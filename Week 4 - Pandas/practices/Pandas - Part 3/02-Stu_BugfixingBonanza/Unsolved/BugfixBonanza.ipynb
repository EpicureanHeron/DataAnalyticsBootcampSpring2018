# %%
# Create a reference to the CSV and import it into a Pandas DataFrame
import pandas as pd
csv_path = "../Resources/EclipseBugs.csv"
eclipse_df = pd.read_csv(csv_path)
eclipse_df.head(5)
# Out:
#    Bug\nID Product Component Assignee    Status Resolution  \
# 0     3638     JDT        UI  aeschli  VERIFIED      FIXED
# 1     3854     JDT        UI  aeschli  VERIFIED      FIXED
# 2     4188     JDT        UI  aeschli  VERIFIED      FIXED
# 3     5115     JDT     Debug  aeschli  VERIFIED      FIXED
# 4     5820     JDT        UI  aeschli  VERIFIED      FIXED
#
#                                              Summary           Changed  \
# 0  Package Viewer: order resource folders before ...    1/17/2002 7:28
# 1             Wrong execution's classpath. (1GEY0W0)    1/18/2002 4:02
# 2                     type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 3  Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 4    Close all editors brings up hierarchy of object  11/20/2001 16:22
#
#   Assignee\nReal\nName Classification  ...  Number of\nComments  \
# 0   Martin Aeschlimann        Eclipse  ...                    3
# 1   Martin Aeschlimann        Eclipse  ...                    5
# 2   Martin Aeschlimann        Eclipse  ...                    3
# 3   Martin Aeschlimann        Eclipse  ...                   10
# 4   Martin Aeschlimann        Eclipse  ...                    5
#
#              Opened            OS Priority       Reporter  \
# 0  10/10/2001 22:58    Windows NT       P1        aeschli
# 1  10/10/2001 23:01    Windows NT       P1    david_audel
# 2  10/10/2001 23:07  Windows 2000       P1    erich_gamma
# 3  10/19/2001 13:41  Windows 2000       P1  darin.eclipse
# 4  11/12/2001 18:18  Windows 2000       P1   jed.anderson
#
#   Reporter\nReal\nName Severity Target\nMilestone Version Votes
# 0   Martin Aeschlimann    major               ---       2     0
# 1          David Audel   normal               ---       2     0
# 2          Erich Gamma   normal               ---       2     0
# 3         Darin Wright   normal               ---       2     0
# 4         Jed Anderson   normal               ---       2     0
#
# [5 rows x 21 columns]

# %%
# Finding the average number of comments per bug
# eclipse_df.groupby(['Number of\nComments'])
average_comments = eclipse_df["Number of\nComments"].mean()
average_comments
# Out:
# 8.75

# %%
# Grouping the DataFrame by "Assignee"
assignee_group = eclipse_df.groupby("Assignee")

# Count how many of each component Assignees worked on and create DataFrame
assignee_work = pd.DataFrame(assignee_group["Component"].value_counts())
assignee_work.head()
# Out:
#                                 Component
# Assignee       Component
# Aaron_Ferguson UI                      10
# Adam_Schlegel  UI                       7
# ChrisAustin    User Assistance          3
# Claude_Knaus   UI                      31
#                Text                     7

# %%
# Rename the "Component" column to "Component Bug Count"
assignee_work = assignee_work.rename(columns={"Component" : "Component Bug Count"})
assignee_work.head()
# Out:
#                                 Component Bug Count
# Assignee       Component
# Aaron_Ferguson UI                                10
# Adam_Schlegel  UI                                 7
# ChrisAustin    User Assistance                    3
# Claude_Knaus   UI                                31
#                Text                               7

# %%
# Find the percentage of bugs overall fixed by each Assignee
#assignee_group["Assignee"].value_counts()
total_bugs = assignee_group["Assignee"].count().sum()
bugs_per_user = assignee_group["Assignee"].value_counts()

user_bug_percent = pd.DataFrame((bugs_per_user/total_bugs)*100)
user_bug_percent
# Out:
#                                          Assignee
# Assignee            Assignee
# Aaron_Ferguson      Aaron_Ferguson           0.10
# Adam_Schlegel       Adam_Schlegel            0.07
# ChrisAustin         ChrisAustin              0.03
# Claude_Knaus        Claude_Knaus             0.38
# Curtis_Windatt      Curtis_Windatt           0.06
# Darin_Swanson       Darin_Swanson            2.97
# James_Moody         James_Moody              0.02
# Karice_McIntyre     Karice_McIntyre          0.04
# Kevin_McGuire       Kevin_McGuire            0.06
# Lars.Vogel          Lars.Vogel               0.03
# Michael_Rennie      Michael_Rennie           0.37
# Mike_Wilson         Mike_Wilson              0.02
# Olivier_Thomann     Olivier_Thomann          0.25
# Platform-UI-Inbox   Platform-UI-Inbox        0.04
# Randy_Giffen        Randy_Giffen             0.08
# Silenio_Quarti      Silenio_Quarti           0.11
# Szymon.Brandys      Szymon.Brandys           0.16
# Tod_Creasey         Tod_Creasey              4.59
# Vikas.Chandra       Vikas.Chandra            0.03
# a.aswani            a.aswani                 0.02
# abhishek.kishore    abhishek.kishore         0.08
# abuzila             abuzila                  0.01
# achilles-86         achilles-86              0.01
# achim.demelt        achim.demelt             0.01
# aclement            aclement                 0.06
# aeschli             aeschli                  6.27
# aferrazz            aferrazz                 0.01
# agarcher            agarcher                 0.23
# ahunter.eclipse     ahunter.eclipse          0.03
# aiproulx            aiproulx                 0.01
# ...                                           ...
# rafael.oliveira     rafael.oliveira          0.01
# raksha.vasisht      raksha.vasisht           0.16
# rthakkar            rthakkar                 0.05
# ryan_cooper         ryan_cooper              0.10
# sarika.sinha        sarika.sinha             0.01
# sasikanth.bharadwaj sasikanth.bharadwaj      0.01
# satyam.kandula      satyam.kandula           0.01
# serge               serge                    0.01
# silvio_boehler      silvio_boehler           0.01
# simon_arsenault     simon_arsenault          0.06
# snorthov            snorthov                 0.02
# sonia_dimitrov      sonia_dimitrov           0.02
# sravankumarl        sravankumarl             0.01
# srikanth_sankaran   srikanth_sankaran        0.02
# stderr              stderr                   0.01
# stephan.herrmann    stephan.herrmann         0.04
# susan               susan                    0.09
# sxenos              sxenos                   0.42
# szymon.ptaszkiewicz szymon.ptaszkiewicz      0.02
# t.s.maeder          t.s.maeder               0.13
# teicher-bugzilla    teicher-bugzilla         0.03
# till_bay            till_bay                 0.21
# tobias_widmer       tobias_widmer            0.38
# tom.schindl         tom.schindl              0.01
# tomasz.zarna        tomasz.zarna             0.09
# unknown             unknown                  0.02
# valentam            valentam                 0.30
# veronika_irvine     veronika_irvine          0.02
# wassim.melhem       wassim.melhem            0.04
# zhiyongl            zhiyongl                 0.01
#
# [205 rows x 1 columns]

# %%
# Merge the "Percent of Total Bugs Assigned" into the DataFrame
assignee_work = assignee_work.merge(user_bug_percent,on="Assignee")

# Remove the extra columns
assignee_work = assignee_work[["Assignee","Percent of Total Bugs","Component","Component Bug Count"]]
assignee_work.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3776ea469fab> in <module>()
#       1 # Merge the "Bug Percentages" into the DataFrame
# ----> 2 assignee_work.merge(user_bug_percent,on="Assignee")
#
# NameError: name 'assignee_work' is not defined
