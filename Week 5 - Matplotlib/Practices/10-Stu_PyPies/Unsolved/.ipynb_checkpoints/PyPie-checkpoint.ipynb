# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["Apple", "Pumpkin", "Chocolate Creme", "Cherry", "Apple Crumb", "Pecan", "Lemon Meringue", "Blueberry", "Key Lime", "Peach"]
bars_in_cities = [47,37,32,27,25,24,24,21,18,16]
# colors = []
explode = (0.2,0,0,0,0,0,0,0,0,0)

# %%
# Tell matplotlib to create a pie chart based upon the above data
plt.pie(bars_in_cities, explode=explode, labels = cities, autopct= "%1.1f%%", shadow = True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x205c72d8f98>,
#   <matplotlib.patches.Wedge at 0x205c72e9860>,
#   <matplotlib.patches.Wedge at 0x205c72f9160>,
#   <matplotlib.patches.Wedge at 0x205c72ffa20>,
#   <matplotlib.patches.Wedge at 0x205c7311320>,
#   <matplotlib.patches.Wedge at 0x205c7317be0>,
#   <matplotlib.patches.Wedge at 0x205c73294e0>,
#   <matplotlib.patches.Wedge at 0x205c7330da0>,
#   <matplotlib.patches.Wedge at 0x205c73406a0>,
#   <matplotlib.patches.Wedge at 0x205c7347f60>],
#  [<matplotlib.text.Text at 0x205c72e0d30>,
#   <matplotlib.text.Text at 0x205c72ef630>,
#   <matplotlib.text.Text at 0x205c72f9ef0>,
#   <matplotlib.text.Text at 0x205c73067f0>,
#   <matplotlib.text.Text at 0x205c73170f0>,
#   <matplotlib.text.Text at 0x205c731f9b0>,
#   <matplotlib.text.Text at 0x205c73302b0>,
#   <matplotlib.text.Text at 0x205c7337b70>,
#   <matplotlib.text.Text at 0x205c7347470>,
#   <matplotlib.text.Text at 0x205c7350d30>],
#  [<matplotlib.text.Text at 0x205c72e92e8>,
#   <matplotlib.text.Text at 0x205c72efba8>,
#   <matplotlib.text.Text at 0x205c72ff4a8>,
#   <matplotlib.text.Text at 0x205c7306d68>,
#   <matplotlib.text.Text at 0x205c7317668>,
#   <matplotlib.text.Text at 0x205c731ff28>,
#   <matplotlib.text.Text at 0x205c7330828>,
#   <matplotlib.text.Text at 0x205c7340128>,
#   <matplotlib.text.Text at 0x205c73479e8>,
#   <matplotlib.text.Text at 0x205c73562e8>])

# %%
# Create axes which are equal so we have a perfect circle
plt.axis("equal")
# Out:
# (-1.324713196122437,
#  1.1147065039510822,
#  -1.1053281099679459,
#  1.1037001240581898)

# %%
# Save an image of our chart and print the final product to the screen
plt.savefig('favorite_pie.png')
plt.show()
